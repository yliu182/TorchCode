# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/06_multihead_attention.ipynb)
#
# # 🔴 Hard: Multi-Head Attention
#
# Implement **Multi-Head Attention** from scratch — the core building block of the Transformer.
#
# $$\text{MultiHead}(Q, K, V) = \text{Concat}(\text{head}_1, \dots, \text{head}_h) W^O$$
# $$\text{head}_i = \text{Attention}(Q W_i^Q,\; K W_i^K,\; V W_i^V)$$
#
# ### Signature
# ```python
# class MultiHeadAttention:
#     def __init__(self, d_model: int, num_heads: int): ...
#     def forward(self, Q, K, V) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - Use `nn.Linear(d_model, d_model)` for `self.W_q`, `self.W_k`, `self.W_v`, `self.W_o`
# - `d_k = d_model // num_heads` per head
# - `forward(Q, K, V)`: Q is `(B, seq_q, d_model)`, K/V are `(B, seq_k, d_model)`
# - Must support **cross-attention** (`seq_q != seq_k`)
# - Do **NOT** use `torch.nn.MultiheadAttention`
# - You **may** use `torch.softmax` and `torch.matmul`
#
# ### Steps
# 1. Project: `q = self.W_q(Q)`, `k = self.W_k(K)`, `v = self.W_v(V)`
# 2. Reshape to `(B, num_heads, seq, d_k)`
# 3. Scaled dot-product attention per head
# 4. Concat heads → `(B, seq_q, d_model)`
# 5. Output projection: `self.W_o(concat)`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import torch.nn as nn
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class MultiHeadAttention:
    def __init__(self, d_model: int, num_heads: int):
        # Initialize W_q, W_k, W_v, W_o
        self.num_heads = num_heads
        self.d_k = d_model // num_heads
        self.d_model = d_model
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)


    def forward(self, Q, K, V):
        # Note that seq_q and seq_k might be defferent
        #
        # If decoder-only, Q, K, V are with same length
        # 
        # If encoder-decoder, Q is from decoder, but K, V are from encoder
        #    the decoder's token looking for encoder's tokens
        B, seq_q, _ = Q.shape
        seq_k = K.shape[1]

        # projection
        q = self.W_q(Q) # (B, seq_q, d_model)
        k = self.W_k(K) # (B, seq_k, d_model)
        v = self.W_v(V) # (B, seq_k, d_model)

        q = q.view(B, seq_q, self.num_heads, self.d_k).transpose(1, 2) #  (B, num_heads, seq_q, d_k)
        k = k.view(B, seq_k, self.num_heads, self.d_k).transpose(1, 2) #  (B, num_heads, seq_k, d_k)
        v = v.view(B, seq_k, self.num_heads, self.d_k).transpose(1, 2) #  (B, num_heads, seq_k, d_k)

        # (B, num_heads, seq_q, seq_k)
        scores = torch.matmul(
            q,
            k.transpose(-2, -1) / (self.d_k ** 0.5)
        )

        # softmax for each q, (B, num_heads, seq_q, seq_k)
        attn = torch.softmax(scores, dim=-1)
        
        out = torch.matmul(attn, v) # (B, num_heads, seq_q, d_k)

        # concat different heads
        # (B, num_heads, seq_q, d_k) -> (B, seq_q, d_model)
        # concat_out = out.transpose(1, 2).contiguous().view(B, seq_q, -1)

        concat_out = out.transpose(1, 2).reshape(B, seq_q, -1)
        return self.W_o(concat_out)

# %%
# 🧪 Debug
torch.manual_seed(0)
mha = MultiHeadAttention(d_model=32, num_heads=4)
print("W_q type:", type(mha.W_q))          # should be nn.Linear
print("W_q.weight shape:", mha.W_q.weight.shape)  # (32, 32)

x = torch.randn(2, 6, 32)
out = mha.forward(x, x, x)
print("Output shape:", out.shape)          # (2, 6, 32)

# Cross-attention
Q = torch.randn(1, 3, 32)
K = torch.randn(1, 7, 32)
V = torch.randn(1, 7, 32)
out2 = mha.forward(Q, K, V)
print("Cross-attn shape:", out2.shape)     # (1, 3, 32)
# Out:
# W_q type: <class 'torch.nn.modules.linear.Linear'>
# W_q.weight shape: torch.Size([32, 32])
# Output shape: torch.Size([2, 6, 32])
# Cross-attn shape: torch.Size([1, 3, 32])

# %%
# ✅ SUBMIT
from torch_judge import check
check("mha")
# Out:
# 🧪 Testing: Multi-Head Attention (Hard)
# ──────────────────────────────────────────────────
#   ✅ [1/6] Output shape (2.6ms)
#   ✅ [2/6] Uses nn.Linear with correct shapes (0.4ms)
#   ✅ [3/6] Numerical correctness vs reference (1.8ms)
#   ✅ [4/6] Gradient flow (1.6ms)
#   ✅ [5/6] Cross-attention (seq_q != seq_k) (0.5ms)
#   ✅ [6/6] Different heads give different outputs (0.8ms)
# ──────────────────────────────────────────────────
#   🎉 All 6 tests passed! (7.8ms total)
#   Progress saved. Run status() to see your dashboard.
